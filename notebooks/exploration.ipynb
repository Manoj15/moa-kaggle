# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Reading Data

# %%
train_x = pd.read_csv('../input/train_features.csv')
train_y_scored = pd.read_csv('../input/train_targets_scored.csv')
train_y_not_scored = pd.read_csv('../input/train_targets_nonscored.csv')
test_x = pd.read_csv('../input/test_features.csv')
sampe_sub = pd.read_csv('../input/sample_submission.csv')
train_x.head()
# Out:
#          sig_id cp_type  cp_time cp_dose     g-0     g-1     g-2     g-3  \
# 0  id_000644bb2  trt_cp       24      D1  1.0620  0.5577 -0.2479 -0.6208
# 1  id_000779bfc  trt_cp       72      D1  0.0743  0.4087  0.2991  0.0604
# 2  id_000a6266a  trt_cp       48      D1  0.6280  0.5817  1.5540 -0.0764
# 3  id_0015fd391  trt_cp       48      D1 -0.5138 -0.2491 -0.2656  0.5288
# 4  id_001626bd3  trt_cp       72      D2 -0.3254 -0.4009  0.9700  0.6919
#
#       g-4     g-5  ...    c-90    c-91    c-92    c-93    c-94    c-95  \
# 0 -0.1944 -1.0120  ...  0.2862  0.2584  0.8076  0.5523 -0.1912  0.6584
# 1  1.0190  0.5207  ... -0.4265  0.7543  0.4708  0.0230  0.2957  0.4899
# 2 -0.0323  1.2390  ... -0.7250 -0.6297  0.6103  0.0223 -1.3240 -0.3174
# 3  4.0620 -0.8095  ... -2.0990 -0.6441 -5.6300 -1.3780 -0.8632 -1.2880
# 4  1.4180 -0.8244  ...  0.0042  0.0048  0.6670  1.0690  0.5523 -0.3031
#
#      c-96    c-97    c-98    c-99
# 0 -0.3981  0.2139  0.3801  0.4176
# ...

# %%
print(train_x.shape)
print(train_x.info())
# Out:
# (23814, 876)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23814 entries, 0 to 23813
# Columns: 876 entries, sig_id to c-99
# dtypes: float64(872), int64(1), object(3)
# memory usage: 159.2+ MB
# None

# %%
print(train_y_scored.shape)
print(train_y_not_scored.shape)
# Out:
# (23814, 207)
# (23814, 403)

# %% [markdown]
# # Data Processing

# %%
# Combining train X and Y
df = pd.merge(train_x, train_y_scored, on = 'sig_id', how = 'left')
df.head()
# Out:
#          sig_id cp_type  cp_time cp_dose     g-0     g-1     g-2     g-3  \
# 0  id_000644bb2  trt_cp       24      D1  1.0620  0.5577 -0.2479 -0.6208
# 1  id_000779bfc  trt_cp       72      D1  0.0743  0.4087  0.2991  0.0604
# 2  id_000a6266a  trt_cp       48      D1  0.6280  0.5817  1.5540 -0.0764
# 3  id_0015fd391  trt_cp       48      D1 -0.5138 -0.2491 -0.2656  0.5288
# 4  id_001626bd3  trt_cp       72      D2 -0.3254 -0.4009  0.9700  0.6919
#
#       g-4     g-5  ...  tropomyosin_receptor_kinase_inhibitor  trpv_agonist  \
# 0 -0.1944 -1.0120  ...                                      0             0
# 1  1.0190  0.5207  ...                                      0             0
# 2 -0.0323  1.2390  ...                                      0             0
# 3  4.0620 -0.8095  ...                                      0             0
# 4  1.4180 -0.8244  ...                                      0             0
#
#    trpv_antagonist  tubulin_inhibitor  tyrosine_kinase_inhibitor  \
# ...

# %% [markdown]
# # Data Exploration

# %%
df.describe(include = 'all')
# Out:
#               sig_id cp_type       cp_time cp_dose           g-0  \
# count          23814   23814  23814.000000   23814  23814.000000
# unique         23814       2           NaN       2           NaN
# top     id_2ec8bdca3  trt_cp           NaN      D1           NaN
# freq               1   21948           NaN   12147           NaN
# mean             NaN     NaN     48.020156     NaN      0.248366
# std              NaN     NaN     19.402807     NaN      1.393399
# min              NaN     NaN     24.000000     NaN     -5.513000
# 25%              NaN     NaN     24.000000     NaN     -0.473075
# 50%              NaN     NaN     48.000000     NaN     -0.008850
# 75%              NaN     NaN     72.000000     NaN      0.525700
# max              NaN     NaN     72.000000     NaN     10.000000
#
#                  g-1           g-2           g-3           g-4           g-5  \
# count   23814.000000  23814.000000  23814.000000  23814.000000  23814.000000
# ...

# %%
df[train_y_scored.columns].describe(include = 'all')
# Out:
#               sig_id  5-alpha_reductase_inhibitor  11-beta-hsd1_inhibitor  \
# count          23814                 23814.000000            23814.000000
# unique         23814                          NaN                     NaN
# top     id_2ec8bdca3                          NaN                     NaN
# freq               1                          NaN                     NaN
# mean             NaN                     0.000714                0.000756
# std              NaN                     0.026709                0.027483
# min              NaN                     0.000000                0.000000
# 25%              NaN                     0.000000                0.000000
# 50%              NaN                     0.000000                0.000000
# 75%              NaN                     0.000000                0.000000
# max              NaN                     1.000000                1.000000
#
#         acat_inhibitor  acetylcholine_receptor_agonist  \
# ...

# %%
df[df.drop(columns=['Result']).eq(0).any(axis=1)]

# %%
temp = df[train_y_scored.columns].sum(axis=1)
idx = temp[temp == 0].index
df[df.index.isin(idx)].describe(include = 'all')
# Out:
#               sig_id cp_type      cp_time cp_dose          g-0          g-1  \
# count           9367    9367  9367.000000    9367  9367.000000  9367.000000
# unique          9367       2          NaN       2          NaN          NaN
# top     id_f90937b7e  trt_cp          NaN      D1          NaN          NaN
# freq               1    7501          NaN    4775          NaN          NaN
# mean             NaN     NaN    48.015373     NaN     0.017800    -0.126930
# std              NaN     NaN    19.390845     NaN     0.961864     0.786366
# min              NaN     NaN    24.000000     NaN    -5.261000    -3.523000
# 25%              NaN     NaN    24.000000     NaN    -0.524250    -0.577200
# 50%              NaN     NaN    48.000000     NaN    -0.070600    -0.066600
# 75%              NaN     NaN    72.000000     NaN     0.412050     0.372900
# max              NaN     NaN    72.000000     NaN     9.908000     5.039000
#
# ...

# %%
idx
# Out:
# Int64Index([    1,     3,     6,     8,    14,    25,    30,    31,    33,
#                35,
#             ...
#             23788, 23790, 23792, 23793, 23795, 23801, 23804, 23806, 23811,
#             23813],
#            dtype='int64', length=9367)

# %%
df.cp_type.value_counts()
# Out:
# trt_cp         21948
# ctl_vehicle     1866
# Name: cp_type, dtype: int64

# %%
df[df.cp_type == "ctl_vehicle"]
# Out:
#              sig_id      cp_type  cp_time cp_dose     g-0     g-1     g-2  \
# 25     id_0054388ec  ctl_vehicle       48      D1 -0.6696 -0.2718 -1.2230
# 38     id_0079af0fb  ctl_vehicle       24      D1 -0.1636 -1.8230 -0.5211
# 40     id_007bfbb91  ctl_vehicle       24      D2 -1.3200 -1.7340 -0.0741
# 47     id_008a986b7  ctl_vehicle       48      D2  0.4860  0.1430  0.5281
# 63     id_009d8340f  ctl_vehicle       24      D2  0.4471 -0.0839 -0.3864
# ...             ...          ...      ...     ...     ...     ...     ...
# 23729  id_ff1f9e5fc  ctl_vehicle       24      D1  0.0465  0.6430 -0.2453
# 23747  id_ff469c482  ctl_vehicle       72      D1 -0.6204 -1.3800 -1.1880
# 23768  id_ff89331ca  ctl_vehicle       72      D2 -0.1051  0.4335  0.3648
# 23793  id_ffd26f361  ctl_vehicle       48      D2  0.6008  0.2781 -0.3319
# 23811  id_fffc1c3f4  ctl_vehicle       48      D2  0.3942  0.3756  0.3109
#
#           g-3     g-4     g-5  ...  tropomyosin_receptor_kinase_inhibitor  \
# ...

# %% [markdown]
# # Model Building
